# %%
# Importing some basic libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading our dataset      # some letter is not recognigible so we use encoding ='latin1'

# %%
df1 = pd.read_csv('zomato.csv', encoding='latin1')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# loading another dataset

# %%
df2=pd.read_excel('Country-Code.xlsx')

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# Merging these two dataset into one

# %%
df= pd.merge(df1,df2)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# we have total 9551 rows × 22 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# So Cuisines column has 9 Null values

# %%
# Dropping all the null rows

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Restaurant ID
# 6317637     1
# 18336474    1
# 18382047    1
# 18441566    1
# 18441669    1
#            ..
# 18451576    1
# 580         1
# 308703      1
# 60          1
# 5927402     1
# Name: count, Length: 9542, dtype: int64
#
#
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: count, Length: 7437, dtype: int64
#
#
# Country Code
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64
#
#
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# ...

# %%
# Restaurant ID column has all the values are unique. so it is better to drop this column

# %%
df.drop('Restaurant ID',axis=1,inplace=True)

# %%
df.head(3)
# Out:
#           Restaurant Name  Country Code              City  \
# 0        Le Petit Souffle           162       Makati City
# 1        Izakaya Kikufuji           162       Makati City
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Dropping the unnecessary columns or the columns whose replica is also present

# %%
df.drop('Locality Verbose',axis=1,inplace =True)

# %%
df.drop('Country Code',axis=1,inplace =True)

# %%
df.drop('Address',axis=1,inplace =True)

# %%
df.drop('Rating color',axis=1,inplace =True)

# %%
df.drop('Rating text',axis=1,inplace =True)

# %%
df.head(3)
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
#
#                                      Locality   Longitude   Latitude  \
# 0   Century City Mall, Poblacion, Makati City  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City  121.056831  14.581404
#
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  \
# 0               Yes                  No                No
# 1               Yes                  No                No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9542 non-null   object
#  1   City                  9542 non-null   object
#  2   Locality              9542 non-null   object
#  3   Longitude             9542 non-null   float64
#  4   Latitude              9542 non-null   float64
#  5   Cuisines              9542 non-null   object
#  6   Average Cost for two  9542 non-null   int64
#  7   Currency              9542 non-null   object
#  8   Has Table booking     9542 non-null   object
#  9   Has Online delivery   9542 non-null   object
#  10  Is delivering now     9542 non-null   object
#  11  Switch to order menu  9542 non-null   object
#  12  Price range           9542 non-null   int64
#  13  Aggregate rating      9542 non-null   float64
#  14  Votes                 9542 non-null   int64
# ...

# %%
# Separating categorical columns and numerical columns

# %%
cat_col=[]
num_col=[]
for i in df.columns:
    if df[i].dtypes == 'object':
        cat_col.append(i)
    else:
        num_col.append(i)

print('cat_col :',cat_col)
print('\n')
print('num_col :',num_col)
# Out:
# cat_col : ['Restaurant Name', 'City', 'Locality', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Country']
#
#
# num_col : ['Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
# Plotting Distplot to check the distribution

# %%
plt.figure(figsize=(15,15),facecolor='white')
p=1
for i in num_col:
    if p<=16:
        ax=plt.subplot(6,3,p)
        sns.distplot(df[i],color='m')
        plt.xlabel(i)
    p+=1
plt.tight_layout()

# %% [markdown]
# 'Longitude', 'Latitude', 'Average Cost for two','Price range', 'Aggregate rating' and 'Votes' columns has the skewness present

# %%
# Plotting boxplot to check the range and outliers present in the columns

# %%
plt.figure(figsize=(15,20),facecolor='white')
p=1
for i in num_col:
    if p<=16:
        ax=plt.subplot(6,3,p)
        sns.boxplot(df[i],color='m')
        plt.xlabel(i)
    p+=1
plt.tight_layout()

# %% [markdown]
# 'Longitude', 'Latitude', 'Average Cost for two' and 'Votes' columns has the outliers present

# %%
#visualize the no of Has Table booking 
ax = sns.countplot(x='Has Table booking',data = df)
df['Has Table booking'].value_counts()
# Out:
# Has Table booking
# No     8384
# Yes    1158
# Name: count, dtype: int64

# %% [markdown]
# the value of NO is 8384 and the value of YES is 1158. so we can see that it is unbalanced

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'City', 'Locality', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Votes', 'Country'],
#       dtype='object')

# %%
#visualize the no of Has Online delivery 
ax = sns.countplot(x='Has Online delivery',data = df)
df['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7091
# Yes    2451
# Name: count, dtype: int64

# %% [markdown]
# Same Has Online delivery column is also unbalanced

# %%
#visualize the no of Is delivering now 
ax = sns.countplot(x='Is delivering now',data = df)
df['Is delivering now'].value_counts()
# Out:
# Is delivering now
# No     9508
# Yes      34
# Name: count, dtype: int64

# %% [markdown]
# This column is totally unbalanced

# %%
df
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546              NamlÛ± Gurme         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548                     Huqqa         ÛÁstanbul
# 9549              Aôôk Kahve         ÛÁstanbul
# 9550  Walter's Coffee Roastery         ÛÁstanbul
#
#                                         Locality   Longitude   Latitude  \
# 0      Century City Mall, Poblacion, Makati City  121.027535  14.565443
# 1     Little Tokyo, Legaspi Village, Makati City  121.014101  14.553708
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City  121.056831  14.581404
# 3         SM Megamall, Ortigas, Mandaluyong City  121.056475  14.585318
# ...

# %%
#transforming datatypes from object to numeric datatype by using OrdianlEncoder
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()

# %%
for i in df.columns:
    if df.dtypes[i] == 'object':
        if i == 'Locality':
            continue
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Restaurant Name   City                                    Locality  \
# 0              3743.0   73.0   Century City Mall, Poblacion, Makati City
# 1              3168.0   73.0  Little Tokyo, Legaspi Village, Makati City
# 2              2893.0   75.0  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3              4700.0   75.0      SM Megamall, Ortigas, Mandaluyong City
# 4              5515.0   75.0      SM Megamall, Ortigas, Mandaluyong City
# ...               ...    ...                                         ...
# 9546           4436.0  139.0                                    Karakí_y
# 9547           1311.0  139.0                                   Koôuyolu
# 9548           3064.0  139.0                                 Kuruí_eôme
# 9549            513.0  139.0                                 Kuruí_eôme
# 9550           7231.0  139.0                                        Moda
#
#        Longitude   Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9542 non-null   float64
#  1   City                  9542 non-null   float64
#  2   Locality              9542 non-null   object
#  3   Longitude             9542 non-null   float64
#  4   Latitude              9542 non-null   float64
#  5   Cuisines              9542 non-null   float64
#  6   Average Cost for two  9542 non-null   int64
#  7   Currency              9542 non-null   float64
#  8   Has Table booking     9542 non-null   float64
#  9   Has Online delivery   9542 non-null   float64
#  10  Is delivering now     9542 non-null   float64
#  11  Switch to order menu  9542 non-null   float64
#  12  Price range           9542 non-null   int64
#  13  Aggregate rating      9542 non-null   float64
#  14  Votes                 9542 non-null   int64
# ...

# %%
# Basically Locality column has high cardinality values so it is better to drop this column otherwise it will tend to overfit

# %%
df.drop('Locality',axis=1,inplace=True)

# %%
# Dropping all the duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9539 entries, 0 to 9550
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9539 non-null   float64
#  1   City                  9539 non-null   float64
#  2   Longitude             9539 non-null   float64
#  3   Latitude              9539 non-null   float64
#  4   Cuisines              9539 non-null   float64
#  5   Average Cost for two  9539 non-null   int64
#  6   Currency              9539 non-null   float64
#  7   Has Table booking     9539 non-null   float64
#  8   Has Online delivery   9539 non-null   float64
#  9   Is delivering now     9539 non-null   float64
#  10  Switch to order menu  9539 non-null   float64
#  11  Price range           9539 non-null   int64
#  12  Aggregate rating      9539 non-null   float64
#  13  Votes                 9539 non-null   int64
#  14  Country               9539 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Restaurant Name         City    Longitude     Latitude     Cuisines  \
# count      9539.000000  9539.000000  9539.000000  9539.000000  9539.000000
# mean       3649.257365    77.571234    64.287103    25.853665   989.172869
# std        2140.230223    22.782640    41.193348    11.005425   514.330237
# min           0.000000     0.000000  -157.948486   -41.330428     0.000000
# 25%        1775.500000    78.500000    77.081603    28.478713   497.000000
# 50%        3591.000000    87.000000    77.192035    28.570444  1126.000000
# 75%        5479.500000    87.000000    77.282042    28.642717  1354.000000
# max        7436.000000   139.000000   174.832089    55.976980  1824.000000
#
#        Average Cost for two     Currency  Has Table booking  \
# count           9539.000000  9539.000000        9539.000000
# mean            1200.593563     3.979558           0.121396
# std            16131.273074     0.912795           0.326604
# ...

# %% [markdown]
# By analysing the statistical summary we can see that 'City', 'Longitude', 'Latitude', 'Average Cost for two', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Price range', 'Aggregate rating', 'Votes', 'Country' these columns has skewness present because there are significant difference between the mean values and the meadian values
#
# And also 'City', 'Longitude', 'Latitude','Average Cost for two', 'Currency','Aggregate rating' and 'Votes' columns has outliers present because there is a huge difference between the 75th percentile and the max values

# %%
df.skew()
# Out:
# Restaurant Name          0.044289
# City                    -1.191692
# Longitude               -2.821678
# Latitude                -3.085358
# Cuisines                -0.305992
# Average Cost for two    35.455687
# Currency                 2.878804
# Has Table booking        2.318909
# Has Online delivery      1.112684
# Is delivering now       16.662824
# Switch to order menu     0.000000
# Price range              0.889453
# Aggregate rating        -0.954242
# Votes                    8.812108
# Country                  3.337169
# dtype: float64

# %%
# Separating skewed column and normal column

# %%
skewed_col=[]
normal_col=[]
for i in df.columns:
    if (df[i].skew() >0.5) or (df[i].skew() <-0.5) :
        skewed_col.append(i)
    else:
        normal_col.append(i)

print('skewed_cols are :',skewed_col)
print('\n')
print("Normal cols are :",normal_col)
# Out:
# skewed_cols are : ['City', 'Longitude', 'Latitude', 'Average Cost for two', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Price range', 'Aggregate rating', 'Votes', 'Country']
#
#
# Normal cols are : ['Restaurant Name', 'Cuisines', 'Switch to order menu']

# %%
skewed_col1=['City', 'Longitude', 'Latitude', 'Average Cost for two', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Aggregate rating', 'Votes', 'Country']

# %%
# removing skewness by using cube root technique

# %%
for i in skewed_col1:
    df[i] = np.cbrt(df[i])

# %%
df.skew()
# Out:
# Restaurant Name          0.044289
# City                    -2.823438
# Longitude               -2.948621
# Latitude                -3.860081
# Cuisines                -0.305992
# Average Cost for two     9.660534
# Currency                -3.600365
# Has Table booking        2.318909
# Has Online delivery      1.112684
# Is delivering now       16.662824
# Switch to order menu     0.000000
# Price range              0.889453
# Aggregate rating        -1.272835
# Votes                    1.206520
# Country                  2.208487
# dtype: float64

# %%
#visualize the no of Price range 
ax = sns.countplot(x='Price range',data = df)
df['Price range'].value_counts()
# Out:
# Price range
# 1    4435
# 2    3113
# 3    1405
# 4     586
# Name: count, dtype: int64

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4435
# 2    3113
# 3    1405
# 4     586
# Name: count, dtype: int64

# %%
# Plotting distplot

# %%
plt.figure(figsize=(15,15),facecolor='white')
p=1
for i in df.columns:
    if p<=16:
        ax=plt.subplot(6,3,p)
        sns.distplot(df[i],color='m')
        plt.xlabel(i)
    p+=1
plt.tight_layout()

# %%
# Ploting boxplot to check the outliers present

# %%
plt.figure(figsize=(15,20),facecolor='white')
p=1
for i in df.columns:
    if p<=16:
        ax=plt.subplot(6,3,p)
        sns.boxplot(df[i],color='m')
        plt.xlabel(i)
    p+=1
plt.tight_layout()

# %% [markdown]
# 'City', 'Longitude', 'Latitude','Average Cost for two', 'Currency','country' and 'Votes' column has outliers present

# %%
# Importing zscore to remove the outliers

# %%
from scipy.stats import zscore

# %%
df.columns
# Out:
# Index(['Restaurant Name', 'City', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Votes', 'Country'],
#       dtype='object')

# %%
a=['Restaurant Name', 'City', 'Longitude', 'Latitude', 'Cuisines',
       'Average Cost for two', 'Currency', 'Has Table booking',
       'Has Online delivery', 'Is delivering now', 'Switch to order menu','Aggregate rating', 'Votes', 'Country']

# %%
cur=df[a]

# %%
z=np.abs(zscore(cur))

# %%
print(np.where(z>3))
# Out:
# (array([   0,    1,    2, ..., 9536, 9537, 9538], dtype=int64), array([6, 6, 6, ..., 6, 6, 6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
# Checking correlation

# %%
corr=df.corr()

# %%
# visualization of correlation by heatmap 
plt.figure(figsize=(20,15))
sns.heatmap(corr,linewidths = .1,fmt='.1g',linecolor = 'black',annot = True,cmap = 'Blues_r')
plt.yticks(rotation =0)
plt.show()

# %%
corr['Switch to order menu'].sort_values(ascending=False)
# Out:
# Restaurant Name        NaN
# City                   NaN
# Longitude              NaN
# Latitude               NaN
# Cuisines               NaN
# Average Cost for two   NaN
# Currency               NaN
# Has Table booking      NaN
# Has Online delivery    NaN
# Is delivering now      NaN
# Switch to order menu   NaN
# Price range            NaN
# Aggregate rating       NaN
# Votes                  NaN
# Country                NaN
# Name: Switch to order menu, dtype: float64

# %%
# Switch to order menu this column has of no use so it is better to drop this column

# %%
df.drop('Switch to order menu',axis=1,inplace=True)

# %%
corr['Price range'].sort_values(ascending=False)
# Out:
# Price range             1.000000
# Votes                   0.519442
# Has Table booking       0.502135
# Average Cost for two    0.449795
# Aggregate rating        0.376875
# Country                 0.169078
# Has Online delivery     0.077736
# Restaurant Name         0.061441
# Is delivering now       0.010922
# Cuisines               -0.005283
# Currency               -0.026864
# Longitude              -0.094960
# City                   -0.143167
# Latitude               -0.168290
# Switch to order menu         NaN
# Name: Price range, dtype: float64

# %% [markdown]
# votes,Has table booking,average cost for two, aggregate rating these columns has relatively high correlation with the target column

# %%
# Separating x and y

# %%
x=df.drop(['Price range'],axis=1)
y = df['Price range']

# %%
x
# Out:
#       Restaurant Name      City  Longitude  Latitude  Cuisines  \
# 0              3743.0  4.179339   4.946463  2.442163     920.0
# 1              3168.0  4.179339   4.946280  2.441507    1111.0
# 2              2893.0  4.217163   4.946862  2.443054    1671.0
# 3              4700.0  4.217163   4.946857  2.443273    1126.0
# 4              5515.0  4.217163   4.946871  2.443224    1122.0
# ...               ...       ...        ...       ...       ...
# 9546           4436.0  5.180101   3.071518  3.448856    1813.0
# 9547           1311.0  5.180101   3.073775  3.448493    1824.0
# 9548           3064.0  5.180101   3.073540  3.449781    1110.0
# 9549            513.0  5.180101   3.073588  3.449842    1657.0
# 9550           7231.0  5.180101   3.073235  3.447790     331.0
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                10.322801   0.00000                1.0                  0.0
# ...

# %%
y
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9539, dtype: int64

# %%
# Standard Scaling
from sklearn.preprocessing import StandardScaler
st= StandardScaler()
x=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x
# Out:
#       Restaurant Name      City  Longitude  Latitude  Cuisines  \
# 0            0.043803 -0.024475   0.656773 -0.289784 -0.134498
# 1           -0.224874 -0.024475   0.656687 -0.290384  0.236878
# 2           -0.353372  0.039534   0.656960 -0.288969  1.325730
# 3            0.490974  0.039534   0.656957 -0.288769  0.266044
# 4            0.871794  0.039534   0.656964 -0.288813  0.258266
# ...               ...       ...        ...       ...       ...
# 9534         0.367616  1.669091  -0.221272  0.630824  1.601831
# 9535        -1.092583  1.669091  -0.220215  0.630492  1.623220
# 9536        -0.273470  1.669091  -0.220325  0.631670  0.234934
# 9537        -1.465460  1.669091  -0.220302  0.631726  1.298508
# 9538         1.673619  1.669091  -0.220468  0.629850 -1.279737
#
#       Average Cost for two   Currency  Has Table booking  Has Online delivery  \
# 0                 0.718328 -11.604076           2.690256            -0.588044
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# checking the VIF 
ds=pd.DataFrame()
ds['Columns']=x.columns
ds['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
ds
# Out:
#                  Columns       vif
# 0        Restaurant Name  1.006806
# 1                   City  1.085798
# 2              Longitude  3.491619
# 3               Latitude  1.528364
# 4               Cuisines  1.033002
# 5   Average Cost for two  1.403806
# 6               Currency  1.414673
# 7      Has Table booking  1.223595
# 8    Has Online delivery  1.175135
# 9      Is delivering now  1.011828
# 10      Aggregate rating  1.748156
# 11                 Votes  2.070407
# 12               Country  2.848047

# %%
# I am not using SMOTE here because our target classes are almost balanced

# %%
#oversampling the data
#from imblearn.over_sampling import SMOTE
#SM = SMOTE()
#x1, y1 = SM.fit_resample(x, y)

# %%
#y1.value_counts()

# %%
# Importing some basic metrices

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# checking the best random_state value

# %%
maxacc=0
maxrs=0
for i in range(200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    RFC=RandomForestClassifier(n_jobs=-1)
    RFC.fit(x_train,y_train)
    pred=RFC.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxacc:
        maxacc=acc
        maxrs=i
print('best acc :',maxacc,  'random_state :',maxrs)
# Out:
# best acc : 0.9853249475890985 random_state : 101

# %%
# separating our train and test dataset based on the best random_state values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=maxrs)

# %%
x_train1,x_test1,y_train1,y_test1=x_train.copy(),x_test.copy(),y_train.copy(),y_test.copy()

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Importing SequentialFeatureSelector for feature selection purpose

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
RFC = RandomForestClassifier()
sfs = SFS(RFC, k_features='best', forward=True, floating=False, scoring='accuracy',cv=5)

sfs.fit(x_train1, y_train1)
# Out:
# SequentialFeatureSelector(estimator=RandomForestClassifier(),
#                           k_features=(1, 13), scoring='accuracy')

# %%
# checking the indexes for the new columns

# %%
sfs.k_feature_idx_
# Out:
# (1, 5, 6, 12)

# %% [markdown]
# So it suggest me to use only 4 columns for the best result

# %%
# checking the new best columns

# %%
selected_columns = sfs.k_feature_names_
print("Selected features: ",selected_columns)
# Out:
# Selected features:  ('City', 'Average Cost for two', 'Currency', 'Country')

# %%
# transforming our dataset for the best columns

# %%
x_train_2 = sfs.transform(x_train1)
x_test_2 = sfs.transform(x_test1)

model = RandomForestClassifier()

print("training",np.mean(cross_val_score(model, x_train_2, y_train, cv=5, scoring='accuracy')))
print("testing",np.mean(cross_val_score(model, x_test_2, y_test, cv=5, scoring='accuracy')))
# Out:
# training 0.9879441353153073
# testing 0.9785120446331643

# %%
x_train
# Out:
#       Restaurant Name      City  Longitude  Latitude  Cuisines  \
# 4712        -1.385091  0.401485   0.333871  0.275306  1.032129
# 3343         0.276967  0.401485   0.334423  0.272636 -0.956970
# 2702        -1.467796  0.401485   0.334137  0.276348  1.032129
# 2114         0.497516 -0.862672   0.333346  0.268675 -0.035335
# 9149        -0.687466  0.886570   0.305523 -0.103003 -0.482542
# ...               ...       ...        ...       ...       ...
# 599          1.749783  1.156158   0.125405  0.162386  0.351596
# 5695         0.933006  0.401485   0.332583  0.273198  0.555756
# 8006         0.963845  0.401485   0.334433  0.272232  0.616032
# 1361         1.170843 -0.862672   0.333446  0.269955 -0.519485
# 1547        -1.391165 -0.862672   0.333350  0.269542 -1.279737
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 4712              0.252356  0.096723          -0.371712            -0.588044
# ...

# %%
# Converting into dataframe

# %%
x_train_sfs = pd.DataFrame(x_train_2,columns=selected_columns)
x_test_sfs= pd.DataFrame(x_test_2,columns=selected_columns)

# %%
x_train_sfs
# Out:
#           City  Average Cost for two  Currency   Country
# 0     0.401485              0.252356  0.096723 -0.247671
# 1     0.401485             -0.110880  0.096723 -0.247671
# 2     0.401485              0.313156  0.096723 -0.247671
# 3    -0.862672              0.313156  0.096723 -0.247671
# 4     0.886570              1.235148  0.096723 -0.247671
# ...        ...                   ...       ...       ...
# 7626  1.156158             -0.833980 -0.973194  3.117877
# 7627  0.401485             -0.537455  0.096723 -0.247671
# 7628  0.401485             -0.028083  0.096723 -0.247671
# 7629 -0.862672              0.120687  0.096723 -0.247671
# 7630 -0.862672              0.252356  0.096723 -0.247671
#
# [7631 rows x 4 columns]

# %%
# Importing almost all the classification algorithmns

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB,GaussianNB
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# making their instances

# %%
RFC=RandomForestClassifier(n_jobs=-1)
ET=ExtraTreesClassifier(n_jobs=-1)
LR=LogisticRegression(n_jobs=-1)
svc=SVC()
GBC=GradientBoostingClassifier()
ADC=AdaBoostClassifier()
BC=BaggingClassifier(n_jobs=-1)
DTC=DecisionTreeClassifier()
KNN=KNeighborsClassifier(n_jobs=-1)
MNB=MultinomialNB()
GNB=GaussianNB()

# %%
loop = [RFC,ET,LR,svc,GBC,ADC,BC,DTC,KNN,GNB]

# %%
from sklearn.metrics import roc_auc_score

# %%
# Running a loop to train all the models separately and checking the corresponding metrices. And compare these metrices with the cross_val_score

# %%
for i in loop:
    i.fit(x_train_sfs,y_train)
    pred=i.predict(x_test_sfs)
    print('This is for :',i)
    print('accuracy score will be :',accuracy_score(y_test,pred))
    print('confusion matrix will be :','\n')
    print(confusion_matrix(y_test,pred))
    print('classification report will be :','\n')
    print(classification_report(y_test,pred))
    
    score= cross_val_score(i,x_train_sfs,y_train,cv=5,scoring='accuracy')
    print('Cross val score will be :',score)
    print('Mean cv :',score.mean())
    print('Difference between cv and roc_auc_score will be :',accuracy_score(y_test,pred)-score.mean())
    print('\n')
# Out:
# This is for : RandomForestClassifier(n_jobs=-1)
# accuracy score will be : 0.9905660377358491
# confusion matrix will be :
#
# [[893   0   0   0]
#  [  4 612   4   0]
#  [  0   3 272   1]
#  [  0   0   6 113]]
# classification report will be :
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       893
#            2       1.00      0.99      0.99       620
#            3       0.96      0.99      0.97       276
#            4       0.99      0.95      0.97       119
#
#     accuracy                           0.99      1908
#    macro avg       0.99      0.98      0.98      1908
# weighted avg       0.99      0.99      0.99      1908
#
# Cross val score will be : [0.98428291 0.98492792 0.99082569 0.98951507 0.98689384]
# Mean cv : 0.9872890848089565
# Difference between cv and roc_auc_score will be : 0.0032769529268925623
#
#
# This is for : ExtraTreesClassifier(n_jobs=-1)
# accuracy score will be : 0.989517819706499
# ...

# %% [markdown]
# So here we can see that RandomForestClassifier model is performing the best because it has achieved accuracy_score of 99.05% ans also The confusion matrix shows that the model has made very few misclassifications. For example, in the second row, the model predicted class 2 correctly for 612 instances but misclassified 4 instances as class 1 and another 4 as class 3.
# The classification report reveals that the model has high precision and recall for all classes.
# The cross-validation scores are also quite high, with a mean of 0.9872890848089565. The small difference between the cross-validation score and the accuracy score suggests that the model is not overfitting and is likely to perform well on unseen data.

# %%
# Importing grid search CV for hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# setting the best parameters for RandomForestClassifier, to feed this into GCV

# %%
parameters = {'n_estimators':[100,150,200],'criterion':['gini','entropy','log_loss'],'n_jobs':[-1],'max_leaf_nodes':[2,4,5,None],'max_depth':[2,3,4,5,None],'bootstrap':['bool',True]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameters,cv=5,n_jobs=-1)

# %%
GCV.fit(x_train_sfs,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': ['bool', True],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [2, 3, 4, 5, None],
#                          'max_leaf_nodes': [2, 4, 5, None],
#                          'n_estimators': [100, 150, 200], 'n_jobs': [-1]})

# %%
# Best parameters

# %%
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_leaf_nodes': None,
#  'n_estimators': 100,
#  'n_jobs': -1}

# %%
# Now use these best parameters to train our model. and this model is going to be our final model

# %%
final_model = RandomForestClassifier(criterion = "gini",bootstrap = True,max_depth=None,max_leaf_nodes=None,n_estimators=100,n_jobs=-1)
final_model.fit(x_train_sfs,y_train)
pred=final_model.predict(x_test_sfs)
acc=accuracy_score(y_test,pred)
print('accuracy_score will be :',acc*100)
# Out:
# accuracy_score will be : 99.0041928721174

# %%
So our final accuracy score is 99%

# %%
# Lets save our model
import joblib
filename = 'zomato_price_range_classification.pkl'
joblib.dump(final_model, filename)
model = joblib.load(filename)

# %%
# Lets test our model

# %%
t=np.array([0.401485,	0.252356,	0.096723,	-0.247671]).reshape(1,-1)
final_model.predict(t)   #2
# Out:
# array([2], dtype=int64)

# %%
t=np.array([0.886570,	1.235148,	0.096723,	-0.247671]).reshape(1,-1)
final_model.predict(t)   #3
# Out:
# array([3], dtype=int64)

# %%
x_train_sfs
# Out:
#           City  Average Cost for two  Currency   Country
# 0     0.401485              0.252356  0.096723 -0.247671
# 1     0.401485             -0.110880  0.096723 -0.247671
# 2     0.401485              0.313156  0.096723 -0.247671
# 3    -0.862672              0.313156  0.096723 -0.247671
# 4     0.886570              1.235148  0.096723 -0.247671
# ...        ...                   ...       ...       ...
# 7626  1.156158             -0.833980 -0.973194  3.117877
# 7627  0.401485             -0.537455  0.096723 -0.247671
# 7628  0.401485             -0.028083  0.096723 -0.247671
# 7629 -0.862672              0.120687  0.096723 -0.247671
# 7630 -0.862672              0.252356  0.096723 -0.247671
#
# [7631 rows x 4 columns]

# %%
y_train
# Out:
# 4722    2
# 3353    1
# 2712    2
# 2123    2
# 9161    3
#        ..
# 608     4
# 5705    1
# 8016    1
# 1370    2
# 1556    2
# Name: Price range, Length: 7631, dtype: int64
